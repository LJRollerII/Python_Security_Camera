# %%
import cv2
import time
import datetime

#To access web camera and view video in python
cap = cv2.VideoCapture(0) #Use number to indicate video camera/device if you mave multiple.

#Setting up face & body detector
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
body_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_fullbody.xml")

recording = True

frame_size = (int(cap.get(3)), int(cap.get(4))) 
#cap. get's us the width as a floating point value, so we use int to round the number.
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter("video.mp4", fourcc, 20, frame_size)

while True:
    _,frame = cap.read() #Underscore is a place holder. cap.read returns something else, but we only care about the frame.
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) #You need grayscale to do the classification
    faces = face_cascade.detectMultiScale(gray, 1.3, 5) 
    bodies = face_cascade.detectMultiScale(gray, 1.3, 5)
    #1.3 is the scale factor it determines the algorithm (scale factor should be in between 1.3 - 1.5) 
    #Lower scale factor number means more accurate algorithm, but slower speed.
    #5 is minimum number of neighbors. This asks how many faces does the camera need to dectect in a vicinity to call it a face?
    #Minimum number of neighbors should be between 3-6. Lower the number, the more faces it dectects and vice versa.
    
    #Write code to start recording if there is at least one face and/or body.
    if len(faces) + len(bodies) > 0:
        recording = True
        
    out.write(frame)
   

    # To draw faces on the video
    # for (x, y, width, height) in faces:
    #    cv2.rectangle(frame, (x, y), (x + width, y + height), (255, 0, 0), 3)

     
    # To draw bodies on the video
    # for (x, y, width, height) in bodies:
    #    cv2.rectangle(frame, (x, y), (x + width, y + height), (255, 0, 0), 3)


  
    cv2.imshow("Camera", frame)
    
    #if statement will quit the program
    if cv2.waitKey(1) == ord('q'):
        break

# Let's write a code to relsease the camera once we're done using it.
out.release() #This saves the video
cap.release()
cv2.destroyAllWindows()
